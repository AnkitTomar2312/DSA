# %%
from sklearn import datasets
iris=datasets.load_iris()
x=iris.data
y=iris.target
import pandas as pd
df=pd.DataFrame(x,columns=iris.feature_names)
from sklearn import model_selection
x_train,x_test,y_train,y_test=model_selection.train_test_split(df,y,test_size=0.7,random_state=42)
# print(x_train.shape,y_train.shape,x_test.shape,y_test.shape)
from sklearn.linear_model import LinearRegression
lnrg=LinearRegression()
lnrg.fit(x_train,y_train)
y_pred=lnrg.predict(x_test)
import matplotlib.pyplot as plt
plt.scatter(y_pred,y_test)
plt.ylabel("Prediction")
plt.xlabel("Test data")
plt.show()

# %%
from sklearn import datasets
from sklearn import model_selection
import pandas as pd
diab=datasets.load_diabetes()
x=diab.data
y=diab.target
diab_df=pd.DataFrame(x,columns=diab.feature_names)
x_train,x_test,y_train,y_test=model_selection.train_test_split(diab_df,y,test_size=0.3, random_state=42)
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (309, 10)
# (133, 10)
# (309,)
# (133,)
